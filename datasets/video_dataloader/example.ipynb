# %%
import yaml
from dataset import BDD100KDataset

with open("config.yaml", encoding="utf-8") as f:
    config = yaml.safe_load(f)

dataset = BDD100KDataset(config)

print("Размер датасета:", len(dataset))

image, target = dataset[0]

print(image.shape)
print(target)
# Out:
# Размер датасета: 3
# torch.Size([3, 720, 1280])
# {'boxes': tensor([[862.9292, 281.3746, 913.4685, 335.4399],
#         [475.3045, 342.4919, 483.5318, 354.2452],
#         [596.6772, 333.7945, 604.9045, 347.8984],
#         [550.0557, 364.3531, 562.9843, 378.4571],
#         [503.0424, 360.8271, 541.8283, 385.5091],
#         [615.8743, 363.1778, 674.6409, 401.9637]]), 'labels': tensor([7, 7, 6, 1, 1, 1]), 'image_id': 0}

# %%
import yaml
from dataloader import create_dataloader

with open("config.yaml", encoding="utf-8") as f:
    config = yaml.safe_load(f)


dataloader = create_dataloader(config)


for images, targets in dataloader:
    print("images:", images.shape)

    print("number of targets:", len(targets))

    for target in targets:
        print("boxes:", target["boxes"].shape)
        print("labels:", target["labels"].shape)

    break
# Out:
# /mnt/d/cv_tomsk/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1102: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# images: torch.Size([1, 3, 720, 1280])
# number of targets: 1
# boxes: torch.Size([22, 4])
# labels: torch.Size([22])

# %%
import yaml
from dataloader import create_video_dataloader

with open("config.yaml", encoding="utf-8") as f:
    config = yaml.safe_load(f)


dataloader = create_video_dataloader(config)


print("Количество samples:", len(dataloader.dataset))


for frames, targets in dataloader:
    print("Frames shape:", frames.shape)
    print("Number of targets:", len(targets))

    for target in targets:
        print("boxes:", target["boxes"].shape, "labels:", target["labels"].shape)
    print(target)
    break
# Out:
# Количество samples: 3
# /mnt/d/cv_tomsk/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1102: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Frames shape: torch.Size([3, 5, 3, 720, 1280])
# Number of targets: 3
# boxes: torch.Size([6, 4]) labels: torch.Size([6])
# boxes: torch.Size([22, 4]) labels: torch.Size([22])
# boxes: torch.Size([16, 4]) labels: torch.Size([16])
# {'boxes': tensor([[2.4478e-01, 1.7687e+02, 9.7176e+01, 4.7305e+02],
#         [5.6788e+01, 1.9045e+02, 3.3950e+02, 3.7758e+02],
#         [3.0450e+02, 2.2546e+02, 3.9335e+02, 3.3989e+02],
#         [3.8931e+02, 2.2142e+02, 4.9567e+02, 3.1431e+02],
#         [5.1452e+02, 2.1334e+02, 5.3067e+02, 2.2950e+02],
#         [5.9260e+02, 2.2680e+02, 6.0606e+02, 2.4161e+02],
#         [6.8684e+02, 1.9719e+02, 7.1107e+02, 2.2815e+02],
#         [8.0396e+02, 2.5104e+02, 1.0880e+03, 5.0144e+02],
#         [7.1511e+02, 2.8065e+02, 8.4974e+02, 3.9105e+02],
#         [6.8684e+02, 2.7258e+02, 7.6223e+02, 3.5335e+02],
#         [6.4645e+02, 2.6181e+02, 7.2319e+02, 3.4797e+02],
#         [6.3837e+02, 2.6315e+02, 6.7607e+02, 3.1566e+02],
#         [5.6971e+02, 2.6854e+02, 5.9529e+02, 2.9277e+02],
#         [5.4952e+02, 2.6315e+02, 5.6837e+02, 2.8469e+02],
#         [6.1818e+02, 2.7527e+02, 6.3972e+02, 2.9142e+02],
#         [5.9373e+02, 2.6687e+02, 6.0597e+02, 2.8523e+02]]), 'labels': tensor([1, 1, 1, 1, 6, 6, 7, 1, 1, 1, 1, 1, 1, 1, 1, 1]), 'image_id': 1}
